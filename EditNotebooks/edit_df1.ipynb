# %%
import pandas as pd
import numpy as np
path = "C:/Users/zainm/OneDrive/Desktop/Projects/MATHCOMP/Given"

# %%
df1 = pd.read_csv('Given/summerOly_hosts.csv')
df1 = df1.drop([5,11,12])
display(df1)
# Out:
#     Year                                               Host
# 0   1896                                     Athens, Greece
# 1   1900                                      Paris, France
# 2   1904                           St. Louis, United States
# 3   1908                             London, United Kingdom
# 4   1912                                  Stockholm, Sweden
# 6   1920                                   Antwerp, Belgium
# 7   1924                                      Paris, France
# 8   1928                             Amsterdam, Netherlands
# 9   1932                         Los Angeles, United States
# 10  1936                                    Berlin, Germany
# 13  1948                             London, United Kingdom
# 14  1952                                  Helsinki, Finland
# 15  1956                               Melbourne, Australia
# 16  1960                                        Rome, Italy
# 17  1964                                       Tokyo, Japan
# ...

# %%
df1['Host'] = (df1['Host'].str.split(",").str[1])
display(df1)
# Out:
#     Year                                               Host
# 0   1896                                             Greece
# 1   1900                                             France
# 2   1904                                      United States
# 3   1908                                     United Kingdom
# 4   1912                                             Sweden
# 6   1920                                            Belgium
# 7   1924                                             France
# 8   1928                                        Netherlands
# 9   1932                                      United States
# 10  1936                                            Germany
# 13  1948                                     United Kingdom
# 14  1952                                            Finland
# 15  1956                                          Australia
# 16  1960                                              Italy
# 17  1964                                              Japan
# ...

# %%
df1.loc[31,'Host'] = "Japan"
display(df1)
# Out:
#     Year             Host
# 0   1896           Greece
# 1   1900           France
# 2   1904    United States
# 3   1908   United Kingdom
# 4   1912           Sweden
# 6   1920          Belgium
# 7   1924           France
# 8   1928      Netherlands
# 9   1932    United States
# 10  1936          Germany
# 13  1948   United Kingdom
# 14  1952          Finland
# 15  1956        Australia
# 16  1960            Italy
# 17  1964            Japan
# 18  1968           Mexico
# 19  1972     West Germany
# 20  1976           Canada
# 21  1980     Soviet Union
# 22  1984    United States
# 23  1988      South Korea
# 24  1992            Spain
# 25  1996    United States
# 26  2000        Australia
# 27  2004           Greece
# 28  2008            China
# 29  2012   United Kingdom
# 30  2016           Brazil
# 31  2020            Japan
# 32  2024           France
# 33  2028    United States
# 34  2032        Australia

# %%
from ass_vals import assign_values
# Out:
# [0, 1, 0, 2, 1, 3]
# {'apple': 0, 'banana': 1, 'cherry': 2, 'date': 3}

# %%
HOST_ARR = np.array(df1['Host'])
assigned_values,val_map= assign_values(HOST_ARR)
print(assigned_values)
print(val_map)
df1['Host'] = assigned_values
display(df1)



HOST_ARR = np.array(df1['Year'])
assigned_values,val_map= assign_values(HOST_ARR)
print(assigned_values)
print(val_map)
df1['Year'] = assigned_values
display(df1)
# Out:
# [0, 1, 2, 3, 4, 5, 1, 6, 2, 7, 3, 8, 9, 10, 11, 12, 13, 14, 15, 2, 16, 17, 2, 9, 0, 18, 3, 19, 20, 1, 2, 9]
# {'\xa0Greece': 0, '\xa0France': 1, '\xa0United States': 2, '\xa0United Kingdom': 3, '\xa0Sweden': 4, '\xa0Belgium': 5, '\xa0Netherlands': 6, '\xa0Germany': 7, '\xa0Finland': 8, '\xa0Australia': 9, '\xa0Italy': 10, '\xa0Japan': 11, '\xa0Mexico': 12, '\xa0West Germany': 13, '\xa0Canada': 14, '\xa0Soviet Union': 15, '\xa0South Korea': 16, '\xa0Spain': 17, '\xa0China': 18, '\xa0Brazil': 19, 'Japan': 20}
#     Year  Host
# 0   1896     0
# 1   1900     1
# 2   1904     2
# 3   1908     3
# 4   1912     4
# 6   1920     5
# 7   1924     1
# 8   1928     6
# 9   1932     2
# 10  1936     7
# 13  1948     3
# 14  1952     8
# 15  1956     9
# 16  1960    10
# 17  1964    11
# 18  1968    12
# 19  1972    13
# 20  1976    14
# 21  1980    15
# 22  1984     2
# 23  1988    16
# 24  1992    17
# 25  1996     2
# 26  2000     9
# 27  2004     0
# 28  2008    18
# 29  2012     3
# ...

# %%
df1.to_csv("df1CSV.csv",index=False)
